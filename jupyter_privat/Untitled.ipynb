# %%
# blab init
import blab
startup_notebook = blab.blab_startup()
# %run $startup_notebook
# Out:
# blab init
# blab found local libs at /media/me/DATA/Dropbox/31_Projekte/01_Python/libs
# Start Time: 20:07:03
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='Beige';this.parentNode.removeChild(this)">
# time: 937 ms

# %%
import numpy      as np
import pandas     as pd 
import bpyth      as bpy
import pandasklar as pak 
#pak.Config.set('VERBOSE', False)
# Out:
# time: 2.76 s

# %%
df = pak.random_perlin( shape=(100,3) )
#df = df.reset_index()
#df = pak.move_cols(df,'index',-1)
#df = pak.rename_col(df,'index','Ho')
df.head(5)
# Out:
#           A         B         C
# 0  0.000000  0.000000  0.000000
# 1  0.023288 -0.037026 -0.036812
# 2  0.043510 -0.072683 -0.065366
# 3  0.069441 -0.091821 -0.093197
# 4  0.109861 -0.099213 -0.132081
# time: 83.4 ms

# %%
pak.mem_usage(df)
# Out:
# '2.3 KB'
# time: 47.2 ms

# %%
raise Stop

# %%
# ?bpy.human_readable_bytes
# Out:
# time: 114 ms
# Signature: bpy.human_readable_bytes(num, suffix='B')
# Docstring: Converts Bytes to human readable size
# File:      /media/me/DATA/Dropbox/31_Projekte/01_Python/git/bpyth/src/bpyth/bpyth_human.py
# Type:      function

# %%
# %matplotlib inline
pak.plot(df)
# Out:
# findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.
# time: 567 ms

# %%
raw = pak.random_series(100, 'p', name='raw')
pak.plot(raw)
# Out:
# time: 539 ms

# %%
result = pak.random_series_perlin( 100, freq=[ 0.1, 0.2, 3,0], op='mult', sc=False) * 10000
result = result.sort_values().reset_index(drop=True)
pak.plot(result)
# Out:
# time: 513 ms

# %%
a = pak.random_series(100, 'a')
pak.plot(a)
# Out:
# time: 597 ms

# %%
a = pak.random_series_descending(100)
pak.plot(a)
# Out:
# time: 575 ms

# %%
import random
# Out:
# time: 35 ms

# %%
random.choice([ 1, 1000, 1000000, 1000000000, -1000, -1000000, -1000000000, ])
# Out:
# -1000000
# time: 57.8 ms
