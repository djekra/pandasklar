# %% [markdown]
# __[Open and try this file online (Colab)](https://colab.research.google.com/github/djekra/pandasklar/blob/master/jupyter/21_Manage_Columns.ipynb)__

# %% [markdown]
# # Manage columns
# * `drop_cols`: Drops a column or a list of columns. Does not throw an error if the column does not exist.
# * `move_cols`: Reorders the columns of a DataFrame. The specified columns are moved to a numerical position or behind a named column.
# * `rename_col`: Renames a column of a DataFrame. If you try to rename a column again, no error is thrown (better for the workflow in jupyter notebooks).
# * `col_names`: Selects column names based on analyse_cols. Useful to apply a method to specific columns of a DataFrame.
# * `write_empty_col`: Writes empty iterables into a column.

# %%
# blab init
try:
    import blab
except ImportError as e:
    # !pip install blab
    import blab    
startup_notebook = blab.blab_startup()
# %run $startup_notebook
# Out:
# blab init
# environment['in_colab']     = False
# environment['dropbox_path'] = /home/me/Data_Linux/Dropbox
# environment['lib_path']     = /home/me/Data_Linux/Dropbox/31_Projekte/01_Python/libs
# Start Time: 21:42:08
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='Beige';this.parentNode.removeChild(this)">

# %%
import pandas     as pd 
import bpyth      as bpy

# pandasklar
try:
    import pandasklar as pak 
except ImportError as e:
    # !pip install pandasklar
    import pandasklar as pak   
    
# verbose
pak.Config.set('VERBOSE', True)

# copy_on_write
pd.set_option("mode.copy_on_write", True)
# Out:
# VERBOSE = True
# --> setting verbose=True as default for all pandasklar functions

# %%
# Test data
df = pak.people()
df
# Out:
#    first_name  age  age_class  postal_code birthplace      secret
# 0     Wilhelm   33         30        66354     Berlin       YqoYA  \
# 1       Willi   31         30        30423     Bremen       iVwiV
# 2       Lilli   36         30        77410     Bremen   a6a6xuaqv
# 3      Dennis   31         30        74666       <NA>       v7ÄPo
# 4     Bastian   34         30        21708     Bremen       dnKÜm
# ..        ...  ...        ...          ...        ...         ...
# 95   Stefanie   27         20        50068     Berlin       QEMZd
# 96      Henry   30         30        48288       <NA>   Öe3g4ÄsEv
# 97      Jakob   30         30        37937     Berlin   E9uä9üWÖV
# 98       John   25         20        42791     Berlin  FGngrqÄxw6
# 99     Vivien   33         30        24996       <NA>     euuiRlb
#
#            features       history
# 0      {H, J, 2, k}  [b, b, a, b]
# 1               {C}     [a, b, c]
# 2            {L, h}     [A, A, A]
# 3   {L, Q, C, E, S}            []
# 4         {p, Y, E}     [c, b, a]
# ..              ...           ...
# 95     {b, a, F, m}     [c, b, a]
# 96              {T}  [A, B, C, C]
# 97           {A, h}  [A, C, C, B]
# 98           {m, a}     [c, b, a]
# 99           {L, h}            []
#
# [100 rows x 8 columns]

# %% [markdown]
# ## drop_cols()

# %%
# ?pak.drop_cols
# Out:
# Signature: pak.drop_cols(df, colnames)
# Docstring:
# Drops a column or a list of columns.
# Does not throw an error if the column does not exist.
# File:      ~/Data_Linux/Dropbox/31_Projekte/01_Python/git/pandasklar/src/pandasklar/pandas.py
# Type:      function

# %%
df = pak.drop_cols(df,'age_class')
df
# Out:
#    first_name  age  postal_code birthplace      secret         features
# 0     Wilhelm   33        66354     Berlin       YqoYA     {H, J, 2, k}  \
# 1       Willi   31        30423     Bremen       iVwiV              {C}
# 2       Lilli   36        77410     Bremen   a6a6xuaqv           {L, h}
# 3      Dennis   31        74666       <NA>       v7ÄPo  {L, Q, C, E, S}
# 4     Bastian   34        21708     Bremen       dnKÜm        {p, Y, E}
# ..        ...  ...          ...        ...         ...              ...
# 95   Stefanie   27        50068     Berlin       QEMZd     {b, a, F, m}
# 96      Henry   30        48288       <NA>   Öe3g4ÄsEv              {T}
# 97      Jakob   30        37937     Berlin   E9uä9üWÖV           {A, h}
# 98       John   25        42791     Berlin  FGngrqÄxw6           {m, a}
# 99     Vivien   33        24996       <NA>     euuiRlb           {L, h}
#
#          history
# 0   [b, b, a, b]
# 1      [a, b, c]
# 2      [A, A, A]
# 3             []
# 4      [c, b, a]
# ..           ...
# 95     [c, b, a]
# 96  [A, B, C, C]
# 97  [A, C, C, B]
# 98     [c, b, a]
# 99            []
#
# [100 rows x 7 columns]

# %%
# drop_cols avoid error messages
df = pak.drop_cols(df,['postal_code','POSTALCODE'])
df
# Out:
#    first_name  age birthplace      secret         features       history
# 0     Wilhelm   33     Berlin       YqoYA     {H, J, 2, k}  [b, b, a, b]
# 1       Willi   31     Bremen       iVwiV              {C}     [a, b, c]
# 2       Lilli   36     Bremen   a6a6xuaqv           {L, h}     [A, A, A]
# 3      Dennis   31       <NA>       v7ÄPo  {L, Q, C, E, S}            []
# 4     Bastian   34     Bremen       dnKÜm        {p, Y, E}     [c, b, a]
# ..        ...  ...        ...         ...              ...           ...
# 95   Stefanie   27     Berlin       QEMZd     {b, a, F, m}     [c, b, a]
# 96      Henry   30       <NA>   Öe3g4ÄsEv              {T}  [A, B, C, C]
# 97      Jakob   30     Berlin   E9uä9üWÖV           {A, h}  [A, C, C, B]
# 98       John   25     Berlin  FGngrqÄxw6           {m, a}     [c, b, a]
# 99     Vivien   33       <NA>     euuiRlb           {L, h}            []
#
# [100 rows x 6 columns]

# %% [markdown]
# ## move_cols()

# %%
# ?pak.move_cols
# Out:
# Signature: pak.move_cols(df, colnames=None, to=0)
# Docstring:
# Reorders the columns of a DataFrame.
# The specified columns are moved to a numerical position or behind a named column.
# If no arguments are given, sorts the columns lexicographically.
#  * colnames: String or list of column names
#  * to:       0: move to the front
#             -1: move to the back
#            <i>: move to position i (buggy)
#      <colname>: move behind a specific column
# File:      ~/Data_Linux/Dropbox/31_Projekte/01_Python/git/pandasklar/src/pandasklar/pandas.py
# Type:      function

# %%
# move to the front
df = pak.move_cols( df, ['secret','birthplace','i_dont_exist'])
df
# Out:
#         secret birthplace first_name  age         features       history
# 0        YqoYA     Berlin    Wilhelm   33     {H, J, 2, k}  [b, b, a, b]
# 1        iVwiV     Bremen      Willi   31              {C}     [a, b, c]
# 2    a6a6xuaqv     Bremen      Lilli   36           {L, h}     [A, A, A]
# 3        v7ÄPo       <NA>     Dennis   31  {L, Q, C, E, S}            []
# 4        dnKÜm     Bremen    Bastian   34        {p, Y, E}     [c, b, a]
# ..         ...        ...        ...  ...              ...           ...
# 95       QEMZd     Berlin   Stefanie   27     {b, a, F, m}     [c, b, a]
# 96   Öe3g4ÄsEv       <NA>      Henry   30              {T}  [A, B, C, C]
# 97   E9uä9üWÖV     Berlin      Jakob   30           {A, h}  [A, C, C, B]
# 98  FGngrqÄxw6     Berlin       John   25           {m, a}     [c, b, a]
# 99     euuiRlb       <NA>     Vivien   33           {L, h}            []
#
# [100 rows x 6 columns]

# %%
# move to the end
df = pak.move_cols( df, ['secret','birthplace','i_dont_exist'], to=-1)
df
# Out:
#    first_name  age         features       history      secret birthplace
# 0     Wilhelm   33     {H, J, 2, k}  [b, b, a, b]       YqoYA     Berlin
# 1       Willi   31              {C}     [a, b, c]       iVwiV     Bremen
# 2       Lilli   36           {L, h}     [A, A, A]   a6a6xuaqv     Bremen
# 3      Dennis   31  {L, Q, C, E, S}            []       v7ÄPo       <NA>
# 4     Bastian   34        {p, Y, E}     [c, b, a]       dnKÜm     Bremen
# ..        ...  ...              ...           ...         ...        ...
# 95   Stefanie   27     {b, a, F, m}     [c, b, a]       QEMZd     Berlin
# 96      Henry   30              {T}  [A, B, C, C]   Öe3g4ÄsEv       <NA>
# 97      Jakob   30           {A, h}  [A, C, C, B]   E9uä9üWÖV     Berlin
# 98       John   25           {m, a}     [c, b, a]  FGngrqÄxw6     Berlin
# 99     Vivien   33           {L, h}            []     euuiRlb       <NA>
#
# [100 rows x 6 columns]

# %%
# move to a specific column
df = pak.move_cols( df, ['secret','birthplace','i_dont_exist'], to='age')
df
# Out:
#    first_name  age      secret birthplace         features       history
# 0     Wilhelm   33       YqoYA     Berlin     {H, J, 2, k}  [b, b, a, b]
# 1       Willi   31       iVwiV     Bremen              {C}     [a, b, c]
# 2       Lilli   36   a6a6xuaqv     Bremen           {L, h}     [A, A, A]
# 3      Dennis   31       v7ÄPo       <NA>  {L, Q, C, E, S}            []
# 4     Bastian   34       dnKÜm     Bremen        {p, Y, E}     [c, b, a]
# ..        ...  ...         ...        ...              ...           ...
# 95   Stefanie   27       QEMZd     Berlin     {b, a, F, m}     [c, b, a]
# 96      Henry   30   Öe3g4ÄsEv       <NA>              {T}  [A, B, C, C]
# 97      Jakob   30   E9uä9üWÖV     Berlin           {A, h}  [A, C, C, B]
# 98       John   25  FGngrqÄxw6     Berlin           {m, a}     [c, b, a]
# 99     Vivien   33     euuiRlb       <NA>           {L, h}            []
#
# [100 rows x 6 columns]

# %%
# move to a specific position
df = pak.move_cols( df, ['secret','birthplace','i_dont_exist'], to=1)
df
# Out:
#    first_name      secret birthplace  age         features       history
# 0     Wilhelm       YqoYA     Berlin   33     {H, J, 2, k}  [b, b, a, b]
# 1       Willi       iVwiV     Bremen   31              {C}     [a, b, c]
# 2       Lilli   a6a6xuaqv     Bremen   36           {L, h}     [A, A, A]
# 3      Dennis       v7ÄPo       <NA>   31  {L, Q, C, E, S}            []
# 4     Bastian       dnKÜm     Bremen   34        {p, Y, E}     [c, b, a]
# ..        ...         ...        ...  ...              ...           ...
# 95   Stefanie       QEMZd     Berlin   27     {b, a, F, m}     [c, b, a]
# 96      Henry   Öe3g4ÄsEv       <NA>   30              {T}  [A, B, C, C]
# 97      Jakob   E9uä9üWÖV     Berlin   30           {A, h}  [A, C, C, B]
# 98       John  FGngrqÄxw6     Berlin   25           {m, a}     [c, b, a]
# 99     Vivien     euuiRlb       <NA>   33           {L, h}            []
#
# [100 rows x 6 columns]

# %% [markdown]
# ## rename_col()

# %%
# ?pak.rename_col
# Out:
# Signature: pak.rename_col(df, name_from, name_to)
# Docstring:
# Renames a column of a DataFrame.
# If you try to rename a column again, no error is thrown (better for the workflow in jupyter notebooks).
# File:      ~/Data_Linux/Dropbox/31_Projekte/01_Python/git/pandasklar/src/pandasklar/pandas.py
# Type:      function

# %%
# do rename
df = pak.rename_col(df, 'age', 'AGE')
df
# Out:
#    first_name      secret birthplace  AGE         features       history
# 0     Wilhelm       YqoYA     Berlin   33     {H, J, 2, k}  [b, b, a, b]
# 1       Willi       iVwiV     Bremen   31              {C}     [a, b, c]
# 2       Lilli   a6a6xuaqv     Bremen   36           {L, h}     [A, A, A]
# 3      Dennis       v7ÄPo       <NA>   31  {L, Q, C, E, S}            []
# 4     Bastian       dnKÜm     Bremen   34        {p, Y, E}     [c, b, a]
# ..        ...         ...        ...  ...              ...           ...
# 95   Stefanie       QEMZd     Berlin   27     {b, a, F, m}     [c, b, a]
# 96      Henry   Öe3g4ÄsEv       <NA>   30              {T}  [A, B, C, C]
# 97      Jakob   E9uä9üWÖV     Berlin   30           {A, h}  [A, C, C, B]
# 98       John  FGngrqÄxw6     Berlin   25           {m, a}     [c, b, a]
# 99     Vivien     euuiRlb       <NA>   33           {L, h}            []
#
# [100 rows x 6 columns]

# %%
# do it again >> no error
pak.rename_col(df, 'age', 'AGE')
# Out:
#    first_name      secret birthplace  AGE         features       history
# 0     Wilhelm       YqoYA     Berlin   33     {H, J, 2, k}  [b, b, a, b]
# 1       Willi       iVwiV     Bremen   31              {C}     [a, b, c]
# 2       Lilli   a6a6xuaqv     Bremen   36           {L, h}     [A, A, A]
# 3      Dennis       v7ÄPo       <NA>   31  {L, Q, C, E, S}            []
# 4     Bastian       dnKÜm     Bremen   34        {p, Y, E}     [c, b, a]
# ..        ...         ...        ...  ...              ...           ...
# 95   Stefanie       QEMZd     Berlin   27     {b, a, F, m}     [c, b, a]
# 96      Henry   Öe3g4ÄsEv       <NA>   30              {T}  [A, B, C, C]
# 97      Jakob   E9uä9üWÖV     Berlin   30           {A, h}  [A, C, C, B]
# 98       John  FGngrqÄxw6     Berlin   25           {m, a}     [c, b, a]
# 99     Vivien     euuiRlb       <NA>   33           {L, h}            []
#
# [100 rows x 6 columns]

# %% [markdown]
# ## col_names()

# %%
# ?pak.col_names
# Out:
# Signature:
# pak.col_names(
#     df,
#     only='',
#     without='XXXXXX',
#     as_list=True,
#     query=None,
#     sort=False,
# )
# Docstring:
# Selects column names based on analyse_cols. Useful to apply a method to specific columns of a DataFrame.
# * only:     Only column names whose datatype begins like this.
# * without:  Without column names whose datatype starts like this
# * as_list:  Output result as list (otherwise as DataFrame, useful for development and control)
# * query:    additional conditions
# * sort:     sorted by nunique
# datatypes are taken from analyse_datatypes, field datatype_short or datatype_instance.
#
# Example: treat all str columns with fillna
# cols = col_names(df, only='str', query='nnan > 0')
# df[cols] = df[cols].fillna('')
# File:      ~/Data_Linux/Dropbox/31_Projekte/01_Python/git/pandasklar/src/pandasklar/analyse.py
# Type:      function

# %%
# have a look at the analyse again
pak.analyse_cols(df)
# Out:
#      col_name datatype_instance   datatype datatype_short datatype_suggest
# 0   __index__             int64   np.int64          int64          np.int8  \
# 1  first_name               str  pd.string         string
# 2      secret               str  pd.string         string
# 3  birthplace               str  pd.string         string
# 4         AGE              int8    pd.Int8           Int8
# 5    features               set     object         object
# 6     history              list     object         object
#
#    is_numeric  is_string  is_hashable  nan_allowed mem_usage  ntypes  nunique
# 0        True      False         True        False    80.0 B       1      100  \
# 1       False       True         True         True   622.0 B       1       70
# 2       False       True         True         True   812.0 B       1      100
# 3       False       True         True         True   607.0 B       1        2
# 4        True      False         True         True    20.0 B       1       20
# 5       False      False        False         True    2.0 KB       1       79
# 6       False      False        False         True   704.0 B       1        9
#
#    nnan  ndups    n    vmin  vmean  vmedian       vmax    vsum
# 0     0      0  100     0.0  49.50     49.5       99.0  4950.0
# 1     0     30  100  Aileen    NaN      NaN     Yvonne     NaN
# 2     0      0  100  0SÄINB    NaN      NaN  üwkkNSeeI     NaN
# 3    28     70  100  Berlin    NaN      NaN     Bremen     NaN
# 4     0     80  100    21.0  30.54     31.0       42.0  3054.0
# 5     0     21  100      {}    NaN      NaN     {L, h}     NaN
# 6     0     91  100      []    NaN      NaN  [c, b, a]     NaN

# %%
# select some columns
pak.col_names(df, only='int', query='nnan == 0', as_list=True )
# Out:
# ['AGE']

# %%
# Example: fillna on all sting columns
df2 = df.copy()
spalten = pak.col_names(df2, only='str', query='nnan > 0')

print('Spalten:',spalten)
print('any_nan before:', pak.any_nan(df2[spalten]))

# apply
df2[spalten] = df2[spalten].fillna('')
print('any_nan after:', pak.any_nan(df2[spalten]))
# Out:
# Spalten: ['birthplace']
# any_nan before: True
# any_nan after: False

# %%
# Example2: astype on all int64 columns
# First: find out suitable data type
pak.type_info('int8').info()
# Out:
# {'instance1': None,
#  'instance2': None,
#  'name': 'np.int8',
#  'framework': 'np',
#  'name_short': 'int8',
#  'name_long': 'np.int8',
#  'class_object': numpy.int8,
#  'is_hashable': True,
#  'nan_allowed': False,
#  'name_instance': '',
#  'xmin': -128,
#  'xmax': 127}

# %%
# astype on all int64 columns
df2 = df.copy()
spalten = pak.col_names(df2, only='int', query='vmin >= 0 and vmax < 127 and nnan == 0') # int_grob only
spalten
# Out:
# ['AGE']

# %%
df2[spalten] = df2[spalten].astype( pak.type_info('int8').class_object  )

# %%
spalten = pak.col_names(df2, only='int')
pak.analyse_cols(df2[spalten])
# Out:
#     col_name datatype_instance  datatype datatype_short datatype_suggest
# 0  __index__             int64  np.int64          int64          np.int8  \
# 1        AGE              int8   np.int8           int8          pd.Int8
#
#    is_numeric  is_string  is_hashable  nan_allowed mem_usage  ntypes  nunique
# 0        True      False         True        False    80.0 B       1      100  \
# 1        True      False         True        False    10.0 B       1       20
#
#    nnan  ndups    n  vmin  vmean  vmedian  vmax    vsum
# 0     0      0  100   0.0  49.50     49.5  99.0  4950.0
# 1     0     80  100  21.0  30.54     31.0  42.0  3054.0

# %% [markdown]
# ## write_empty_col

# %%
# ?pak.write_empty_col
# Out:
# Signature: pak.write_empty_col(df, col_name, content)
# Docstring:
# Writes empty iterables into a column and sets datatype.
# * content: Can be 'list','set','dict','defaultdict', 'string' or any empty iterable.
# Example: write_empty_col(df,'mycol','list') writes empty lists in mycol.
# File:      ~/Data_Linux/Dropbox/31_Projekte/01_Python/git/pandasklar/src/pandasklar/pandas.py
# Type:      function

# %%
pak.write_empty_col(df,'mycol','defaultdict')
# Out:
#    first_name      secret birthplace  AGE         features       history mycol
# 0     Wilhelm       YqoYA     Berlin   33     {H, J, 2, k}  [b, b, a, b]    {}
# 1       Willi       iVwiV     Bremen   31              {C}     [a, b, c]    {}
# 2       Lilli   a6a6xuaqv     Bremen   36           {L, h}     [A, A, A]    {}
# 3      Dennis       v7ÄPo       <NA>   31  {L, Q, C, E, S}            []    {}
# 4     Bastian       dnKÜm     Bremen   34        {p, Y, E}     [c, b, a]    {}
# ..        ...         ...        ...  ...              ...           ...   ...
# 95   Stefanie       QEMZd     Berlin   27     {b, a, F, m}     [c, b, a]    {}
# 96      Henry   Öe3g4ÄsEv       <NA>   30              {T}  [A, B, C, C]    {}
# 97      Jakob   E9uä9üWÖV     Berlin   30           {A, h}  [A, C, C, B]    {}
# 98       John  FGngrqÄxw6     Berlin   25           {m, a}     [c, b, a]    {}
# 99     Vivien     euuiRlb       <NA>   33           {L, h}            []    {}
#
# [100 rows x 7 columns]

# %%
pak.write_empty_col(df,'mycol',list())
# Out:
#    first_name      secret birthplace  AGE         features       history mycol
# 0     Wilhelm       YqoYA     Berlin   33     {H, J, 2, k}  [b, b, a, b]    []
# 1       Willi       iVwiV     Bremen   31              {C}     [a, b, c]    []
# 2       Lilli   a6a6xuaqv     Bremen   36           {L, h}     [A, A, A]    []
# 3      Dennis       v7ÄPo       <NA>   31  {L, Q, C, E, S}            []    []
# 4     Bastian       dnKÜm     Bremen   34        {p, Y, E}     [c, b, a]    []
# ..        ...         ...        ...  ...              ...           ...   ...
# 95   Stefanie       QEMZd     Berlin   27     {b, a, F, m}     [c, b, a]    []
# 96      Henry   Öe3g4ÄsEv       <NA>   30              {T}  [A, B, C, C]    []
# 97      Jakob   E9uä9üWÖV     Berlin   30           {A, h}  [A, C, C, B]    []
# 98       John  FGngrqÄxw6     Berlin   25           {m, a}     [c, b, a]    []
# 99     Vivien     euuiRlb       <NA>   33           {L, h}            []    []
#
# [100 rows x 7 columns]
