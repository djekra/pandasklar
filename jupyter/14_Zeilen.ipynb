# %% [markdown]
# # Zeilen
# - reindizieren

# %%
# blab init
import blab
startup_notebook = blab.blab_startup()
# %run $startup_notebook
# Out:
# dropbox_path = /Data/Dropbox
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='DarkGray';this.parentNode.removeChild(this)">
# time: 4.56 ms (started: 2022-02-14 07:49:17 +00:00)

# %%
import numpy      as np
import pandas     as pd 
import bpyth      as bpy
import pandasklar as pak
# Out:
# time: 314 ms (started: 2022-02-14 07:49:17 +00:00)

# %% [markdown]
# ## Zeilennamen und Zeilenindizies

# %%
# Testdaten
df = pak.leute()
df
# Out:
#     vorname  alter  altersklasse    plz geburtsstadt    passwort  \
# 0      Kira     31            30  33284         <NA>    v8LXz5ZU
# 1     Karla     35            30  19254       Bremen  eXtUHCr7dL
# 2     Fritz     38            30  53936       Berlin  CFebfsFdJx
# 3      Erik     24            20  91119       Bremen   KCDFRUkuM
# 4    Frieda     27            20  70745       Berlin   YaXVlhY6Q
# ..      ...    ...           ...    ...          ...         ...
# 95    Paula     30            30  80744         <NA>    ivTut4öm
# 96    Erich     33            30  47498       Berlin      FAÖ2ow
# 97  Lennart     34            30  99228       Bremen     jSeÖ7fÜ
# 98     Erna     30            30  47797         <NA>   1kvXahÜ9g
# 99   Dagmar     32            30  23145       Bremen   AurCVäiqT
#
#            merkmale       history
# 0               {x}  [A, B, C, C]
# 1   {1, R, c, 4, f}     [A, B, C]
# 2   {n, i, 3, e, x}        [A, x]
# 3      {Y, G, F, L}            []
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)
# time: 1.61 ms (started: 2022-02-14 07:49:18 +00:00)

# %%
neuer_index = pak.random_series(df.shape[0], 'string', len_min=3, len_max=3, p_dup=0)
neuer_index
# Out:
# 0     Ami
# 1     vBW
# 2     S7e
# 3     tE4
# 4     Üh5
#      ...
# 95    j4a
# 96    XgK
# 97    hIE
# 98    e0i
# 99    mLa
# Name: random, Length: 100, dtype: string
# time: 7.87 ms (started: 2022-02-14 07:49:18 +00:00)

# %%
# Zeilenindex zuweisen
df.index = neuer_index # das kann eine Series oder eine Liste sein
df
# Out:
#         vorname  alter  altersklasse    plz geburtsstadt    passwort  \
# random
# Ami        Kira     31            30  33284         <NA>    v8LXz5ZU
# vBW       Karla     35            30  19254       Bremen  eXtUHCr7dL
# S7e       Fritz     38            30  53936       Berlin  CFebfsFdJx
# tE4        Erik     24            20  91119       Bremen   KCDFRUkuM
# Üh5      Frieda     27            20  70745       Berlin   YaXVlhY6Q
# ...         ...    ...           ...    ...          ...         ...
# j4a       Paula     30            30  80744         <NA>    ivTut4öm
# XgK       Erich     33            30  47498       Berlin      FAÖ2ow
# hIE     Lennart     34            30  99228       Bremen     jSeÖ7fÜ
# e0i        Erna     30            30  47797         <NA>   1kvXahÜ9g
# mLa      Dagmar     32            30  23145       Bremen   AurCVäiqT
#
#                merkmale       history
# random
# Ami                 {x}  [A, B, C, C]
# vBW     {1, R, c, 4, f}     [A, B, C]
# ...

# %%
df = pak.reset_index(df)
df
# Out:
#    random  vorname  alter  altersklasse    plz geburtsstadt    passwort  \
# 0     Ami     Kira     31            30  33284         <NA>    v8LXz5ZU
# 1     vBW    Karla     35            30  19254       Bremen  eXtUHCr7dL
# 2     S7e    Fritz     38            30  53936       Berlin  CFebfsFdJx
# 3     tE4     Erik     24            20  91119       Bremen   KCDFRUkuM
# 4     Üh5   Frieda     27            20  70745       Berlin   YaXVlhY6Q
# ..    ...      ...    ...           ...    ...          ...         ...
# 95    j4a    Paula     30            30  80744         <NA>    ivTut4öm
# 96    XgK    Erich     33            30  47498       Berlin      FAÖ2ow
# 97    hIE  Lennart     34            30  99228       Bremen     jSeÖ7fÜ
# 98    e0i     Erna     30            30  47797         <NA>   1kvXahÜ9g
# 99    mLa   Dagmar     32            30  23145       Bremen   AurCVäiqT
#
#            merkmale       history
# 0               {x}  [A, B, C, C]
# ...

# %%
df = df.set_index('vorname')
df
# Out:
#         random  alter  altersklasse    plz geburtsstadt    passwort  \
# vorname
# Kira       Ami     31            30  33284         <NA>    v8LXz5ZU
# Karla      vBW     35            30  19254       Bremen  eXtUHCr7dL
# Fritz      S7e     38            30  53936       Berlin  CFebfsFdJx
# Erik       tE4     24            20  91119       Bremen   KCDFRUkuM
# Frieda     Üh5     27            20  70745       Berlin   YaXVlhY6Q
# ...        ...    ...           ...    ...          ...         ...
# Paula      j4a     30            30  80744         <NA>    ivTut4öm
# Erich      XgK     33            30  47498       Berlin      FAÖ2ow
# Lennart    hIE     34            30  99228       Bremen     jSeÖ7fÜ
# Erna       e0i     30            30  47797         <NA>   1kvXahÜ9g
# Dagmar     mLa     32            30  23145       Bremen   AurCVäiqT
#
#                 merkmale       history
# vorname
# Kira                 {x}  [A, B, C, C]
# Karla    {1, R, c, 4, f}     [A, B, C]
# ...
